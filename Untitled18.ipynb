# %%
# !pip install py_vollib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import norm

# %%
from datetime import datetime

# %%
df = pd.read_csv("/content/NIFTY-25JAN24-01JAN24.csv")
df = df.dropna()
df.head()
# Out:
#   datetime  strike_price right    open    high     low   close  open_interest  \
# 0    09:21         17500    CE  4250.0  4250.0  4250.0  4250.0         106000
# 1    09:30         17500    CE  4250.0  4250.0  4250.0  4250.0              0
# 2    09:31         17500    CE  4250.0  4250.0  4250.0  4250.0              0
# 3    09:32         17500    CE  4250.0  4250.0  4250.0  4250.0              0
# 4    09:33         17500    CE  4250.0  4250.0  4250.0  4250.0              0
#
#    volume
# 0     500
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print(df.columns)
# Out:
# Index(['datetime', 'strike_price', 'right', 'open', 'high', 'low', 'close',
#        'open_interest', 'volume'],
#       dtype='object')

# %%
r=0.05
vol=0.05

# %%
#varias
df["S"] = df["low"]+df["high"]/2
df["r"] = input("enter the risk free rate")
df["hours"] = df["datetime"].str.split(":")
df["vol"] = input("enter the volatility")
df["k"] = df["strike_price"]
# Out:
# enter the risk free rate0.4
# enter the volatility0.4
# enter the volatility0.4

# %%
d1= (math.log(S/K)+(r+00.5*(vol)**2)*T)/(vol*math.sqrt(T))
d2= d1-vol*math.sqrt(T)

# %%
C=S*norm.cdf(d1)-K*math.exp(-r*T)*norm.cdf(d2)
print(C)
# Out:
# 4.080503068330934

# %%
P=K*math.exp(-r*T)*norm.cdf(-d2)-S*norm.cdf(-d1)
print(P)
# Out:
# 1.0928995494642386
